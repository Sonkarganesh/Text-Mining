# %%
#Import libraries
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import string # special operations on strings
import spacy # language models

from matplotlib.pyplot import imread
from matplotlib import pyplot as plt
from wordcloud import WordCloud
# %matplotlib inline

# %%
# Import extracted amazon reviews Dataset
#(How to Extract amazon reviews - Refer webscrapping using beautifulsoup(librarie).ipynb)
df=pd.read_csv("C:\\Users\\GANESH\\Downloads\\boatAirdopes-141 Reviews.csv")
df
# Out:
#     Unnamed: 0                                             Review
# 0            0    I have seen a lot of negative reviews for th...
# 1            1    Battery life on single charge says 6 hours o...
# 2            2    The best feature about this earphones is IWP...
# 3            3    Reviewing this TWS approx. 4 months, and fou...
# 4            4    I am writing a true review after around a we...
# 5            5                      The media could not be loa...
# 6            6    Don't even think of buying it's made of bad ...
# 7            7    you really cant expect more from earbuds at ...
# 8            8                      The media could not be loa...
# 9            9    Decent product. Fits comfortable in ears for...
# 10          10    I am a programmer with a taste for music. I ...
# 11          11    This Airdopes 141 is good for first time use...
# 12          12    There is constant hissing noise that remains...
# 13          13    Guys you must note this. When ever I play an...
# 14          14    Worst product till now from boat, the sound ...
# 15          15                               Super good sound no1
# 16          16    -- About Amazon --I am highly disappointed f...
# 17          17    There is some cracking sound in the left ear...
# 18          18    Really unhappy with the buy and they won't e...
# 19          19                      The media could not be loa...
# 20          20    Build quality is good, sound is fine but noi...
# 21          21    I don't know what to say. I bought it a week...
# 22          22                              Worth for this budget
# 23          23    Excellent battery backup, This is a fourth d...
# 24          24                      The media could not be loa...
# 25          25    While in driving mode it's not useful but 🎵 ...
# 26          26    1 star for seller as they sent opened box wi...
# 27          27                      The media could not be loa...
# 28          28    today I rcvd this boat airdopes and when I o...
# 29          29    Item received with broken seal and the produ...
# 30          30                               Already used product
# 31          31    I got this at a discount the during the prim...
# 32          32    Pros:1)Call clarity over earphones is mind-b...
# 33          33    My review is a little bit long(sorry!) but I...
# 34          34                      The media could not be loa...
# 35          35    Pros - 1. Earbuds are super comfortable in e...
# 36          36    The earbuds look so pro and expensive. Feels...
# 37          37    I will keep this short and simple. Kindly no...
# 38          38    Product is cheap in quality and also looks.T...
# 39          39    Quality Average,  But after using more than ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  40 non-null     int64
#  1   Review      40 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 768.0+ bytes

# %%
dfnew=df.drop(columns=['Unnamed: 0'])

# %%
dfnew
# Out:
#                                                Review
# 0     I have seen a lot of negative reviews for th...
# 1     Battery life on single charge says 6 hours o...
# 2     The best feature about this earphones is IWP...
# 3     Reviewing this TWS approx. 4 months, and fou...
# 4     I am writing a true review after around a we...
# 5                       The media could not be loa...
# 6     Don't even think of buying it's made of bad ...
# 7     you really cant expect more from earbuds at ...
# 8                       The media could not be loa...
# 9     Decent product. Fits comfortable in ears for...
# 10    I am a programmer with a taste for music. I ...
# 11    This Airdopes 141 is good for first time use...
# 12    There is constant hissing noise that remains...
# 13    Guys you must note this. When ever I play an...
# 14    Worst product till now from boat, the sound ...
# 15                               Super good sound no1
# 16    -- About Amazon --I am highly disappointed f...
# 17    There is some cracking sound in the left ear...
# 18    Really unhappy with the buy and they won't e...
# 19                      The media could not be loa...
# 20    Build quality is good, sound is fine but noi...
# 21    I don't know what to say. I bought it a week...
# 22                              Worth for this budget
# 23    Excellent battery backup, This is a fourth d...
# 24                      The media could not be loa...
# 25    While in driving mode it's not useful but 🎵 ...
# 26    1 star for seller as they sent opened box wi...
# 27                      The media could not be loa...
# 28    today I rcvd this boat airdopes and when I o...
# 29    Item received with broken seal and the produ...
# 30                               Already used product
# 31    I got this at a discount the during the prim...
# 32    Pros:1)Call clarity over earphones is mind-b...
# 33    My review is a little bit long(sorry!) but I...
# 34                      The media could not be loa...
# 35    Pros - 1. Earbuds are super comfortable in e...
# 36    The earbuds look so pro and expensive. Feels...
# 37    I will keep this short and simple. Kindly no...
# 38    Product is cheap in quality and also looks.T...
# 39    Quality Average,  But after using more than ...

# %%
import re #regular expression
import string

def clean_text(text):
    '''Make text lowercase, remove text in square brackets, remove punctuation and remove words containing numbers.'''
    text = text.lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\w*\d\w*', '', text)
    text = re.sub("[0-9" "]+"," ",text)
    text = re.sub('[‘’“”…]', '', text)
    return text

clean = lambda x: clean_text(x)

# %%
cleaned_df = df.Review.apply(clean)
cleaned_df
# Out:
# 0       i have seen a lot of negative reviews for th...
# 1       battery life on single charge says  hours on...
# 2       the best feature about this earphones is iwp...
# 3       reviewing this tws approx  months and found ...
# 4       i am writing a true review after around a we...
# 5                         the media could not be loa...
# 6       dont even think of buying its made of bad pl...
# 7       you really cant expect more from earbuds at ...
# 8                         the media could not be loa...
# 9       decent product fits comfortable in ears for ...
# 10      i am a programmer with a taste for music i l...
# 11      this airdopes  is good for first time user s...
# 12      there is constant hissing noise that remains...
# 13      guys you must note this when ever i play any...
# 14      worst product till now from boat the sound q...
# 15                                    super good sound
# 16       about amazon i am highly disappointed from ...
# 17      there is some cracking sound in the left ear...
# 18      really unhappy with the buy and they wont ev...
# 19                        the media could not be loa...
# 20      build quality is good sound is fine but nois...
# 21      i dont know what to say i bought it a week a...
# 22                                worth for this budget
# 23      excellent battery backup this is a fourth da...
# 24                        the media could not be loa...
# 25      while in driving mode its not useful but 🎵 g...
# 26       star for seller as they sent opened box wit...
# 27                        the media could not be loa...
# 28      today i rcvd this boat airdopes and when i o...
# 29      item received with broken seal and the produ...
# 30                                 already used product
# 31      i got this at a discount the during the prim...
# 32       clarity over earphones is mindboggling to s...
# 33      my review is a little bit longsorry but i ha...
# 34                        the media could not be loa...
# 35      pros   earbuds are super comfortable in ears...
# 36      the earbuds look so pro and expensive feels ...
# 37      i will keep this short and simple kindly not...
# 38      product is cheap in quality and also looksth...
# 39      quality average  but after using more than  ...
# Name: Review, dtype: object

# %%
#Word frequency
freq = pd.Series(' '.join(cleaned_df).split()).value_counts()[:20] # for top 20
freq
# Out:
# the        202
# is         156
# and        117
# to          90
# it          88
# i           84
# a           77
# of          77
# for         64
# you         59
# not         58
# in          57
# good        52
# on          46
# this        43
# but         40
# with        40
# quality     35
# its         34
# are         32
# dtype: int64

# %%
from nltk.corpus import stopwords
stop = stopwords.words('english')
cleaned_df = cleaned_df.apply(lambda x: " ".join(x for x in x.split() if x not in stop))

# %%
#word frequency after removal of stopwords
freq_Sw = pd.Series(' '.join(cleaned_df).split()).value_counts()[:20] # for top 20
freq_Sw
# Out:
# good        52
# quality     35
# sound       29
# battery     28
# use         27
# case        26
# product     23
# one         21
# even        19
# hours       19
# airdopes    18
# charge      17
# also        16
# music       16
# time        16
# bass        15
# dont        15
# like        15
# charging    14
# noise       14
# dtype: int64

# %%
# count vectoriser tells the frequency of a word.
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np
vectorizer = CountVectorizer(min_df = 1, max_df = 0.9)
X = vectorizer.fit_transform(cleaned_df)
word_freq_df = pd.DataFrame({'term': vectorizer.get_feature_names(), 'occurrences':np.asarray(X.sum(axis=0)).ravel().tolist()})
word_freq_df['frequency'] = word_freq_df['occurrences']/np.sum(word_freq_df['occurrences'])

# %%
word_freq_df.head(30)
# Out:
#           term  occurrences  frequency
# 0         able            1   0.000411
# 1     abruptly            1   0.000411
# 2       absent            1   0.000411
# 3   absolutely            1   0.000411
# 4   acceptable            4   0.001644
# 5        accha            1   0.000411
# 6          ace            1   0.000411
# 7       across            1   0.000411
# 8       action            3   0.001233
# 9       active            1   0.000411
# 10  additional            1   0.000411
# 11    adequate            1   0.000411
# 12      adjust            2   0.000822
# 13   adjusting            1   0.000411
# 14      adkust            1   0.000411
# 15  advertised            1   0.000411
# 16      affect            1   0.000411
# 17         ago            1   0.000411
# 18         air            3   0.001233
# 19    aircraft            1   0.000411
# 20     airdope            1   0.000411
# 21    airdopes           18   0.007398
# 22     airpods            1   0.000411
# 23        aise            1   0.000411
# 24       alert            1   0.000411
# 25       allgo            1   0.000411
# 26       allow            1   0.000411
# 27      almost            2   0.000822
# 28     already            4   0.001644
# 29        also           16   0.006576

# %%
#TFIDF - Term frequency inverse Document Frequencyt
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(stop_words='english', max_features= 1000, max_df = 0.5, smooth_idf=True) #keep top 1000 words
doc_vec = vectorizer.fit_transform(cleaned_df)
names_features = vectorizer.get_feature_names()
dense = doc_vec.todense()
denselist = dense.tolist()
df = pd.DataFrame(denselist, columns = names_features)

# %%
df
# Out:
#         able  abruptly    absent  absolutely  acceptable     accha       ace  \
# 0   0.000000  0.000000  0.000000    0.000000    0.000000  0.000000  0.000000
# 1   0.000000  0.000000  0.000000    0.000000    0.000000  0.000000  0.000000
# 2   0.000000  0.000000  0.000000    0.000000    0.000000  0.000000  0.000000
# 3   0.000000  0.000000  0.000000    0.000000    0.000000  0.000000  0.000000
# 4   0.049313  0.000000  0.049313    0.000000    0.000000  0.000000  0.000000
# 5   0.000000  0.000000  0.000000    0.000000    0.000000  0.000000  0.112501
# 6   0.000000  0.000000  0.000000    0.000000    0.000000  0.000000  0.000000
# 7   0.000000  0.000000  0.000000    0.000000    0.000000  0.000000  0.000000
# 8   0.000000  0.000000  0.000000    0.000000    0.000000  0.000000  0.000000
# 9   0.000000  0.000000  0.000000    0.000000    0.000000  0.000000  0.000000
# 10  0.000000  0.000000  0.000000    0.000000    0.247747  0.000000  0.000000
# 11  0.000000  0.000000  0.000000    0.000000    0.000000  0.000000  0.000000
# 12  0.000000  0.000000  0.000000    0.000000    0.000000  0.000000  0.000000
# 13  0.000000  0.000000  0.000000    0.000000    0.000000  0.000000  0.000000
# 14  0.000000  0.000000  0.000000    0.000000    0.000000  0.000000  0.000000
# 15  0.000000  0.000000  0.000000    0.000000    0.000000  0.000000  0.000000
# 16  0.000000  0.000000  0.000000    0.000000    0.071950  0.000000  0.000000
# 17  0.000000  0.000000  0.000000    0.000000    0.000000  0.000000  0.000000
# 18  0.000000  0.000000  0.000000    0.000000    0.000000  0.000000  0.000000
# 19  0.000000  0.000000  0.000000    0.000000    0.000000  0.000000  0.000000
# 20  0.000000  0.000000  0.000000    0.000000    0.000000  0.000000  0.000000
# 21  0.000000  0.000000  0.000000    0.000000    0.000000  0.090318  0.000000
# 22  0.000000  0.000000  0.000000    0.000000    0.000000  0.000000  0.000000
# 23  0.000000  0.000000  0.000000    0.000000    0.000000  0.000000  0.000000
# 24  0.000000  0.000000  0.000000    0.000000    0.000000  0.000000  0.000000
# 25  0.000000  0.000000  0.000000    0.000000    0.000000  0.000000  0.000000
# 26  0.000000  0.000000  0.000000    0.000000    0.000000  0.000000  0.000000
# 27  0.000000  0.000000  0.000000    0.000000    0.000000  0.000000  0.000000
# 28  0.000000  0.000000  0.000000    0.000000    0.000000  0.000000  0.000000
# 29  0.000000  0.000000  0.000000    0.000000    0.000000  0.000000  0.000000
# 30  0.000000  0.000000  0.000000    0.000000    0.000000  0.000000  0.000000
# 31  0.000000  0.000000  0.000000    0.000000    0.000000  0.000000  0.000000
# 32  0.000000  0.000000  0.000000    0.000000    0.000000  0.000000  0.000000
# 33  0.000000  0.063573  0.000000    0.000000    0.000000  0.000000  0.000000
# 34  0.000000  0.000000  0.000000    0.000000    0.000000  0.000000  0.000000
# 35  0.000000  0.000000  0.000000    0.137748    0.000000  0.000000  0.000000
# 36  0.000000  0.000000  0.000000    0.000000    0.000000  0.000000  0.000000
# 37  0.000000  0.000000  0.000000    0.000000    0.000000  0.000000  0.000000
# 38  0.000000  0.000000  0.000000    0.000000    0.000000  0.000000  0.000000
# 39  0.000000  0.000000  0.000000    0.000000    0.000000  0.000000  0.000000
#
#       action    active  additional  ...     yahan      year     years  \
# 0   0.000000  0.000000    0.000000  ...  0.000000  0.000000  0.000000
# 1   0.000000  0.000000    0.000000  ...  0.000000  0.000000  0.000000
# 2   0.000000  0.000000    0.142738  ...  0.000000  0.000000  0.000000
# 3   0.000000  0.000000    0.000000  ...  0.000000  0.000000  0.000000
# 4   0.000000  0.000000    0.000000  ...  0.000000  0.000000  0.049313
# 5   0.000000  0.000000    0.000000  ...  0.000000  0.000000  0.000000
# 6   0.000000  0.000000    0.000000  ...  0.000000  0.000000  0.000000
# 7   0.000000  0.000000    0.000000  ...  0.000000  0.000000  0.000000
# 8   0.000000  0.000000    0.000000  ...  0.000000  0.000000  0.000000
# 9   0.000000  0.000000    0.000000  ...  0.000000  0.000000  0.000000
# 10  0.000000  0.091845    0.000000  ...  0.000000  0.000000  0.000000
# 11  0.000000  0.000000    0.000000  ...  0.000000  0.000000  0.000000
# 12  0.000000  0.000000    0.000000  ...  0.000000  0.000000  0.000000
# 13  0.000000  0.000000    0.000000  ...  0.000000  0.000000  0.000000
# 14  0.000000  0.000000    0.000000  ...  0.000000  0.000000  0.000000
# 15  0.000000  0.000000    0.000000  ...  0.000000  0.000000  0.000000
# 16  0.240061  0.000000    0.000000  ...  0.000000  0.000000  0.000000
# 17  0.000000  0.000000    0.000000  ...  0.000000  0.000000  0.000000
# 18  0.000000  0.000000    0.000000  ...  0.000000  0.000000  0.000000
# 19  0.000000  0.000000    0.000000  ...  0.000000  0.000000  0.000000
# 20  0.000000  0.000000    0.000000  ...  0.000000  0.000000  0.000000
# 21  0.000000  0.000000    0.000000  ...  0.090318  0.000000  0.000000
# 22  0.000000  0.000000    0.000000  ...  0.000000  0.000000  0.000000
# 23  0.000000  0.000000    0.000000  ...  0.000000  0.000000  0.000000
# 24  0.000000  0.000000    0.000000  ...  0.000000  0.000000  0.000000
# 25  0.000000  0.000000    0.000000  ...  0.000000  0.000000  0.000000
# 26  0.000000  0.000000    0.000000  ...  0.000000  0.000000  0.000000
# 27  0.000000  0.000000    0.000000  ...  0.000000  0.000000  0.000000
# 28  0.000000  0.000000    0.000000  ...  0.000000  0.000000  0.000000
# 29  0.000000  0.000000    0.000000  ...  0.000000  0.000000  0.000000
# 30  0.000000  0.000000    0.000000  ...  0.000000  0.000000  0.000000
# 31  0.000000  0.000000    0.000000  ...  0.000000  0.000000  0.000000
# 32  0.000000  0.000000    0.000000  ...  0.000000  0.000000  0.000000
# 33  0.000000  0.000000    0.000000  ...  0.000000  0.063573  0.000000
# 34  0.000000  0.000000    0.000000  ...  0.000000  0.000000  0.000000
# 35  0.000000  0.000000    0.000000  ...  0.000000  0.000000  0.000000
# 36  0.000000  0.000000    0.000000  ...  0.000000  0.000000  0.000000
# 37  0.000000  0.000000    0.000000  ...  0.000000  0.000000  0.000000
# 38  0.000000  0.000000    0.000000  ...  0.000000  0.000000  0.000000
# 39  0.000000  0.000000    0.000000  ...  0.000000  0.000000  0.000000
#
#          yeh      yes     youll     youre   youtube      zero   zindagi
# 0   0.000000  0.00000  0.144601  0.000000  0.000000  0.000000  0.000000
# 1   0.000000  0.00000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2   0.000000  0.00000  0.000000  0.000000  0.000000  0.000000  0.000000
# 3   0.000000  0.00000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4   0.000000  0.00000  0.000000  0.000000  0.000000  0.098625  0.000000
# 5   0.000000  0.00000  0.101155  0.186210  0.000000  0.000000  0.000000
# 6   0.000000  0.00000  0.000000  0.000000  0.000000  0.000000  0.000000
# 7   0.000000  0.00000  0.000000  0.000000  0.000000  0.000000  0.000000
# 8   0.000000  0.00000  0.000000  0.000000  0.000000  0.000000  0.000000
# 9   0.000000  0.00000  0.000000  0.000000  0.000000  0.000000  0.000000
# 10  0.000000  0.00000  0.000000  0.076010  0.000000  0.000000  0.000000
# 11  0.000000  0.00000  0.000000  0.000000  0.000000  0.000000  0.000000
# 12  0.000000  0.00000  0.000000  0.000000  0.000000  0.000000  0.000000
# 13  0.000000  0.00000  0.000000  0.000000  0.204741  0.000000  0.000000
# 14  0.000000  0.00000  0.000000  0.000000  0.000000  0.000000  0.000000
# 15  0.000000  0.00000  0.000000  0.000000  0.000000  0.000000  0.000000
# 16  0.000000  0.00000  0.000000  0.000000  0.000000  0.000000  0.000000
# 17  0.000000  0.00000  0.000000  0.000000  0.000000  0.000000  0.000000
# 18  0.000000  0.00000  0.000000  0.000000  0.000000  0.000000  0.000000
# 19  0.000000  0.00000  0.000000  0.000000  0.000000  0.000000  0.000000
# 20  0.000000  0.00000  0.000000  0.000000  0.000000  0.000000  0.000000
# 21  0.090318  0.00000  0.000000  0.000000  0.000000  0.000000  0.090318
# 22  0.000000  0.00000  0.000000  0.000000  0.000000  0.000000  0.000000
# 23  0.000000  0.00000  0.000000  0.000000  0.000000  0.000000  0.000000
# 24  0.000000  0.00000  0.000000  0.205781  0.000000  0.000000  0.000000
# 25  0.000000  0.00000  0.000000  0.000000  0.000000  0.000000  0.000000
# 26  0.000000  0.00000  0.000000  0.000000  0.000000  0.000000  0.000000
# 27  0.000000  0.00000  0.000000  0.000000  0.000000  0.000000  0.000000
# 28  0.000000  0.00000  0.000000  0.000000  0.000000  0.000000  0.000000
# 29  0.000000  0.00000  0.000000  0.000000  0.000000  0.000000  0.000000
# 30  0.000000  0.00000  0.000000  0.000000  0.000000  0.000000  0.000000
# 31  0.000000  0.00000  0.000000  0.000000  0.000000  0.000000  0.000000
# 32  0.000000  0.00000  0.000000  0.000000  0.000000  0.000000  0.000000
# 33  0.000000  0.00000  0.000000  0.000000  0.000000  0.000000  0.000000
# 34  0.000000  0.00000  0.000000  0.000000  0.000000  0.000000  0.000000
# 35  0.000000  0.00000  0.000000  0.000000  0.000000  0.000000  0.000000
# 36  0.000000  0.00000  0.000000  0.000000  0.000000  0.000000  0.000000
# 37  0.000000  0.17351  0.000000  0.000000  0.000000  0.000000  0.000000
# 38  0.000000  0.00000  0.000000  0.000000  0.000000  0.000000  0.000000
# 39  0.000000  0.00000  0.000000  0.000000  0.000000  0.000000  0.000000
#
# [40 rows x 998 columns]

# %%
#Bi-gram
def get_top_n2_words(corpus, n=None):
    vec1 = CountVectorizer(ngram_range=(2,2),  #for tri-gram, put ngram_range=(3,3)
            max_features=2000).fit(corpus)
    bag_of_words = vec1.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in     
                  vec1.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], 
                reverse=True)
    return words_freq[:n]

# %%
top2_words = get_top_n2_words(cleaned_df, n=200) #top 200
top2_df = pd.DataFrame(top2_words)
top2_df.columns=["Bi-gram", "Freq"]
top2_df.head()
# Out:
#               Bi-gram  Freq
# 0       sound quality    13
# 1        battery life     8
# 2  noise cancellation     7
# 3         media could     6
# 4        could loaded     6

# %%
#Bi-gram plot
import matplotlib.pyplot as plt
import seaborn as sns
top20_bigram = top2_df.iloc[0:20,:]
fig = plt.figure(figsize = (10, 5))
plot=sns.barplot(x=top20_bigram["Bi-gram"],y=top20_bigram["Freq"])
plot.set_xticklabels(rotation=45,labels = top20_bigram["Bi-gram"])
# Out:
# [Text(0, 0, 'sound quality'),
#  Text(1, 0, 'battery life'),
#  Text(2, 0, 'noise cancellation'),
#  Text(3, 0, 'media could'),
#  Text(4, 0, 'could loaded'),
#  Text(5, 0, 'good sound'),
#  Text(6, 0, 'price range'),
#  Text(7, 0, 'right one'),
#  Text(8, 0, 'quality good'),
#  Text(9, 0, 'battery backup'),
#  Text(10, 0, 'build quality'),
#  Text(11, 0, 'single charge'),
#  Text(12, 0, 'bass good'),
#  Text(13, 0, 'also good'),
#  Text(14, 0, 'boat airdopes'),
#  Text(15, 0, 'latency lag'),
#  Text(16, 0, 'quality bass'),
#  Text(17, 0, 'single touch'),
#  Text(18, 0, 'listen music'),
#  Text(19, 0, 'one thing')]

# %%
#Tri-gram
def get_top_n3_words(corpus, n=None):
    vec1 = CountVectorizer(ngram_range=(3,3), 
           max_features=2000).fit(corpus)
    bag_of_words = vec1.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in     
                  vec1.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], 
                reverse=True)
    return words_freq[:n]

# %%
top3_words = get_top_n3_words(cleaned_df, n=200)
top3_df = pd.DataFrame(top3_words)
top3_df.columns=["Tri-gram", "Freq"]

# %%
top3_df
# Out:
#                        Tri-gram  Freq
# 0            media could loaded     6
# 1            sound quality bass     3
# 2    passive noise cancellation     2
# 3              good price range     2
# 4                bass good mids     2
# ..                          ...   ...
# 195         quality sound entry     1
# 196           sound entry level     1
# 197            level tws simply     1
# 198          tws simply amazing     1
# 199         simply amazing bass     1
#
# [200 rows x 2 columns]

# %%
top20_trigram = top3_df.iloc[0:20,:]
fig = plt.figure(figsize = (10, 5))
plot=sns.barplot(x=top20_trigram["Tri-gram"],y=top20_trigram["Freq"])
plot.set_xticklabels(rotation=45,labels = top20_trigram["Tri-gram"])
# Out:
# [Text(0, 0, 'media could loaded'),
#  Text(1, 0, 'sound quality bass'),
#  Text(2, 0, 'passive noise cancellation'),
#  Text(3, 0, 'good price range'),
#  Text(4, 0, 'bass good mids'),
#  Text(5, 0, 'latency lag voice'),
#  Text(6, 0, 'voice call quality'),
#  Text(7, 0, 'good battery life'),
#  Text(8, 0, 'seen lot negative'),
#  Text(9, 0, 'lot negative reviews'),
#  Text(10, 0, 'negative reviews earbuds'),
#  Text(11, 0, 'reviews earbuds however'),
#  Text(12, 0, 'bad really cheap'),
#  Text(13, 0, 'really cheap inr'),
#  Text(14, 0, 'cheap inr build'),
#  Text(15, 0, 'build quality taken'),
#  Text(16, 0, 'quality taken hit'),
#  Text(17, 0, 'taken hit however'),
#  Text(18, 0, 'hit however matters'),
#  Text(19, 0, 'matters sound quality')]

# %%
string_Total = " ".join(cleaned_df)

# %%
#wordcloud for entire corpus
from wordcloud import WordCloud
wordcloud_stw = WordCloud(
                background_color= 'black',
                width = 3000,
                height = 2000
                ).generate(string_Total)
plt.imshow(wordcloud_stw)

# %%
# Parts Of Speech (POS) Tagging
nlp=spacy.load('en_core_web_sm')

one_block=string_Total
doc_block=nlp(one_block)
spacy.displacy.render(doc_block,style='ent',jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">seen lot negative reviews earbuds however bad really cheap inr build quality taken hit however matters sound quality stellar price already lot earbuds ranging price greatthe battery life though good claimed however
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     hours
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  earbuds close
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     hours
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  case much better competitioni
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  gripe eartips sort oval shape youll need find proper seal try different ear tips given box battery life single charge says
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     hours
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     amazon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  says
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     hours
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  boat website means battery life mentioned probably mentioned single ear usage unfair hours website says get minutes maximum calls lasting much longer please look elsewhere every meeting embarrassing change headset middle meeting saying charge recommended music case bass average best feature earphones iwp instant wake pair technology open lid case earphones connect phonedevice followed battery backupthese good listening music binging videos definitely suitable workout ratingvery bad calls even though passive noise cancellation virtue fit mics sensitive surrounding noise dont pick want use calls want use noisy environmentthe led indicators flashy additional aircraft likeallover steal deal price stated purposehope helps purchase decision 👍 reviewing tws approx
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     months
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  found tws pretty good price range ear phones comes rectangular charging case provides charging buds case sturdy solid built material plastic glossy plastic looks premium quality shining leds case gives indicator charging left case charging lit increasing gradient show case charging fully charged case leds leds lits continuously showing case fully chargedsound quality nutshell good satisfactory contrary expected good quality sound entry level tws simply amazing bass good mids nice terrible also good tried earphones every music output satisfactory rate sound quality scale always lacuna grey types soo infinitesimally scope mentionlatency basically used music movies games worked great delay observedcharging time approx hrslongevity working good point review
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     last months
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  beencomfort light weight comfortable fits good ears falls walking runningin good tws wanna enjoy music without nitpicking earphones writing true review
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     around week
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  long use boat airdopes mic average voice feels little modulated mic provided case little bulky due longer battery life get used
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     days
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  case quality decent case lid feels like built crappy plastic doesnt feel robust stable airdopes based bluetooth v later work great devices bluetooth version ie newer however case older versions lot latency lag personally use laptop work great however connect android phone bluetooth v experience horrendous many problems like latency lag voice breaks etc even bt backwards compatible experience latency lag voice break calling whatsapp calling playing simple mobile games despite problem streaming songs lot voice leakage use percent volume laptop mobile phones tweak voice also kind high able listen anything percent anyhow ideal level movies games well ears hurt prolonged usage dont select right size air caps sizes already provided inside biggest con using airdopes windows cannot use airdopes inbuilt mic together windows doesnt allow even try hard use mic airdopes output speaker together windows issue manageable big problem voice control option absent airdopes volume cant controlled airdopes control device also big problem sound quality bass great battery life great easily use
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     hours
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  continuous charge quickly feel even greater enable surround sound using windows connectivity great soon open case automatically detect connect available devices paired earlier within literally
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     zero
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  latency
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     zero
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  lag connected bluetooth version used laptop played games like cs go valorant gta games issue gaming support mono audio use one airdope time instead using provided
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  warranty easily replace

# %%
for token in doc_block[100:200]:
    print(token,token.pos_)
# Out:
# charge NOUN
# recommended VERB
# music NOUN
# case NOUN
# bass NOUN
# average ADJ
# best ADJ
# feature NOUN
# earphones NOUN
# iwp VERB
# instant NOUN
# wake VERB
# pair NOUN
# technology NOUN
# open ADJ
# lid ADJ
# case NOUN
# earphones NOUN
# connect VERB
# phonedevice NOUN
# followed VERB
# battery NOUN
# backupthese ADJ
# good ADJ
# listening NOUN
# music NOUN
# binging VERB
# videos NOUN
# definitely ADV
# suitable ADJ
# workout NOUN
# ratingvery NOUN
# bad ADJ
# calls NOUN
# even ADV
# though SCONJ
# passive ADJ
# noise NOUN
# cancellation NOUN
# virtue NOUN
# fit ADJ
# mics NOUN
# sensitive ADJ
# surrounding VERB
# noise NOUN
# do AUX
# nt PART
# pick VERB
# want ADJ
# use NOUN
# calls NOUN
# want VERB
# use VERB
# noisy ADJ
# environmentthe PRON
# led VERB
# indicators NOUN
# flashy ADJ
# additional ADJ
# aircraft NOUN
# likeallover NOUN
# steal PROPN
# deal NOUN
# price NOUN
# stated VERB
# purposehope NOUN
# helps VERB
# purchase VERB
# decision NOUN
# 👍 NOUN
# reviewing VERB
# tws SCONJ
# approx ADJ
# months NOUN
# found VERB
# tws SCONJ
# pretty ADV
# good ADJ
# price NOUN
# range NOUN
# ear NOUN
# phones NOUN
# comes VERB
# rectangular ADJ
# charging NOUN
# case NOUN
# provides VERB
# charging VERB
# buds NOUN
# case NOUN
# sturdy ADJ
# solid ADJ
# built VERB
# material NOUN
# plastic NOUN
# glossy ADJ
# plastic NOUN
# looks VERB
# premium ADJ
# quality NOUN

# %%
# Filtering the nouns and verbs only
nouns_verbs=[token.text for token in doc_block if token.pos_ in ('NOUN','VERB')]
print(nouns_verbs[100:200])
# Out:
# ['want', 'use', 'led', 'indicators', 'aircraft', 'likeallover', 'deal', 'price', 'stated', 'purposehope', 'helps', 'purchase', 'decision', '👍', 'reviewing', 'months', 'found', 'price', 'range', 'ear', 'phones', 'comes', 'charging', 'case', 'provides', 'charging', 'buds', 'case', 'built', 'material', 'plastic', 'plastic', 'looks', 'quality', 'shining', 'leds', 'case', 'gives', 'indicator', 'charging', 'case', 'charging', 'lit', 'increasing', 'gradient', 'show', 'case', 'charging', 'charged', 'case', 'leds', 'leds', 'lits', 'showing', 'case', 'chargedsound', 'quality', 'nutshell', 'contrary', 'expected', 'quality', 'sound', 'entry', 'level', 'bass', 'mids', 'tried', 'earphones', 'music', 'output', 'rate', 'sound', 'quality', 'scale', 'types', 'scope', 'mentionlatency', 'used', 'music', 'movies', 'games', 'worked', 'delay', 'observedcharging', 'time', 'working', 'point', 'review', 'months', 'beencomfort', 'weight', 'fits', 'ears', 'falls', 'walking', 'runningin', 'enjoy', 'music', 'nitpicking', 'earphones']

# %%
# Counting the noun & verb tokens
from sklearn.feature_extraction.text import CountVectorizer
cv=CountVectorizer()

X=cv.fit_transform(nouns_verbs)
sum_words=X.sum(axis=0)

words_freq=[(word,sum_words[0,idx]) for word,idx in cv.vocabulary_.items()]
words_freq=sorted(words_freq, key=lambda x: x[1], reverse=True)

wd_df=pd.DataFrame(words_freq)
wd_df.columns=['word','count']
wd_df[0:10] # viewing top ten results
# Out:
#       word  count
# 0  quality     35
# 1  battery     28
# 2      use     27
# 3     case     26
# 4  product     23
# 5    hours     19
# 6    sound     19
# 7   charge     17
# 8    music     16
# 9     time     16
